# %% [markdown]
# # County-level election results vs. US News ranking for Power 5 colleges

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

x = np.array([-0.53, -0.39, -0.39, -0.29, -0.28, -0.25, -0.25, -0.22, -0.21, -0.20, -0.15, -0.11, -0.07, -0.05, -0.05, -0.03, 0, 0.01, 0.01, 0.02, 0.02, 0.03, 0.04, 0.06, 0.09, 0.1, 0.1, 0.11, 0.11, 0.13, 0.13, 0.15, 0.15, 0.16, 0.18, 0.18, 0.21, 0.21, 0.21, 0.22, 0.23, 0.23, 0.26, 0.27, 0.28, 0.28, 0.29, 0.3, 0.33, 0.33, 0.34, 0.34, 0.38, 0.38, 0.39, 0.4, 0.4, 0.4, 0.42, 0.42, 0.44, 0.45, 0.51, 0.52, 0.52, 0.54, 0.56, 0.62, 0.75])
y = np.array([80, 109, 214, 91, 105, 51, 196, 171, 171, 109, 132, 63, 189, 105, 222, 121, 46, 165, 214, 18, 51, 63, 152, 144, 189, 41, 121, 109, 136, 179, 121, 46, 152, 109, 179, 152, 73, 30, 70, 54, 91, 109, 33, 58, 73, 18, 37, 63, 27, 15, 121, 24, 152, 98, 46, 144, 30, 4, 6, 54, 21, 33, 27, 39, 46, 17, 98, 6, 44])

m, b, p, r, stderr = stats.linregress(x, y)

fig, ax = plt.subplots()
ax.scatter(x, y)

plt.plot(x, m*x+b, color='red')
plt.ylabel("US News Rank")
plt.xlabel(f"Percent vote won by Harris, r^2 = {r ** 2}")

plt.show()

# %% [markdown]
# ## Results
# While there is a correlation between election results and US News rank amont P4 universities, it's so small that it's basically nonexistent
